# %% [markdown]
# # <center>Challenge 2<center>

# %% [markdown]
# <p>Team Name: Nerds Cluster
# <p>Student Names: Rowan Merritt and Chloe Catanese
# <p>Student W#s: W0749642 and W0722937

# %% [markdown]
# ## Instructions
# Use generic coding style unless hard-coded values are really necessary.<br>
# Your code must be efficient and use self-explanatory naming.<br>
# Use appropriate Python library methods for each task instead of using loops.<br>
# Run your entire code and save. Then submit this <b>saved</b> copy.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import logging
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pandas as pd


import scipy.stats as stats
logger = logging.getLogger(__name__)

# %% [markdown]
# ## Prepare Data

# %%
logger.info('Generating datasets...')
random = np.random
normalDataset = random.normal(loc=10.0, scale=4.0, size=(1000))
                                # where loc=mean and scale=variance
uniformDataset = random.uniform(low=4.0, high=16.0, size=(1000))
logger.info('Datasets created!')

# ** Reference(s)
# * For ".random.normal": https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html#numpy-random-normal
# * For ".random.uniform": https://numpy.org/doc/stable/reference/random/generated/numpy.random.uniform.html#numpy.random.uniform
# **

# %% [markdown]
# # Q-Q Plot

# %%
logger.info('Generating Q-Q Plot...')

# Define quantiles
quantiles = [0.1, 0.25, 0.5, 0.75]
normal_quantiles = np.quantile(normalDataset, quantiles)
uniform_quantiles = np.quantile(uniformDataset, quantiles)

plt.figure(figsize=(10, 6))


# Q-Q plot for normal dataset
plt.subplot(1, 2, 1)
sm.qqplot(normalDataset, line='45', ax=plt.gca())
plt.title('Q-Q Plot: Normal Distribution')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')

# Add quantile markers to the normal dataset plot
for q in quantiles:
    plt.plot(stats.norm.ppf(q, loc=10, scale=2), np.quantile(normalDataset, q), 'ro')
    plt.text(stats.norm.ppf(q, loc=10, scale=2), np.quantile(normalDataset, q), f'{int(q * 100)}%', fontsize=10, ha='center', va='center')


# Q-Q plot for uniform dataset
plt.subplot(1, 2, 2)
sm.qqplot(uniformDataset, line='45', ax=plt.gca())
plt.title('Q-Q Plot: Uniform Distribution')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')

for q in quantiles:
    plt.plot(stats.norm.ppf(q, loc=10, scale=2), np.quantile(uniformDataset, q), 'ro')
    plt.text(stats.norm.ppf(q, loc=10, scale=2), np.quantile(uniformDataset, q), f'{int(q * 100)}%', fontsize=10, ha='center', va='center')


plt.tight_layout()
plt.show()

# Create Q-Q plot
plt.show()
axis.set_title('Q-Q Plot')
axis.set_xlabel('Theoretical Quantiles')
axis.set_ylabel('Sample Quantiles')
axis.grid(True)
plt.show()

# ** Reference(s)
# * https://www.geeksforgeeks.org/quantile-quantile-plots/
#* https://www.statology.org/q-q-plot-python/
# **

# %% [markdown]
# ## Analysis of Outcome

# %% [markdown]
# When the data points are in normal disturbution, the Q-Q plot takes a image of a line moving at a constant upward slope which implies symmetric distribution. As for uniform distribution, the Q-Q plot shows a negative skew.

# %% [markdown]
# # Parallel-Coordinates Plot

# %%
data = {
    "Id":[1,2,3,4,5,6,7,8,9],
    "Age":[50,25,30,65,55,75,45,70,40],
    "Weight":[160,130,200,150,170,165,180,190,200],
    "Height":[5,6,4,4.5,5.2,4.8,5.8,4.8,5.8]
}

df = pd.DataFrame(data)

#plot
plt.figure(figsize = (10,6))
pd.plotting.parallel_coordinates(df, class_column = 'Id', cols=['Age','Weight','Height'])

plt.title('Parallel Coordinates Plot')
plt.xlabel('Attributes')
plt.ylabel('Values')

plt.show()

# %% [markdown]
# ## Analysis of Outcome

# %% [markdown]
# There seems to be an even distribution of ages and heights. There are more individuals that have higher weights.
#
# There is no clear relationship between an individual's weight and height based on the plot. There are people who are heights but higher weights like the 30-year-old. There are people with larger heights and smaller weights like the 25 year old. This also showcases the lack of relationship between age and the attributes height and weight. The youngest two individuals, age 25 and 30, weigh both the least and the most and are the tallest and the shortest, respectively.
